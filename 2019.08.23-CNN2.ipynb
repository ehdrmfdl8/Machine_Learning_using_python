# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime

mnist = input_data.read_data_sets("MNIST_data/", one_hot = True)

print("")
print("train.num = ", mnist.train.num_examples)
print("test.num = ", mnist.test.num_examples)
print("validation.num = ", mnist.validation.num_examples)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
#
# train.num =  55000
# test.num =  10000
# validation.num =  5000

# %%
learning_rate = 0.001 # 학습율
epochs = 30 # 반복횟수
batch_size = 100 #한번에 입력으로 주어지는 MNIST 개수

# %%
X = tf.placeholder(tf.float32, [None, 784]) # 28 x 28

T = tf.placeholder(tf.float32, [None, 10]) # 정답데이터 10개

A1 = tf.reshape(X, [-1, 28, 28, 1]) # image 28 x 28 x 1 (black / white)

# %%
W2 = tf.Variable(tf.random_normal([5, 5, 1, 32], stddev = 0.01))

b2 = tf.Variable(tf.constant(0.1, shape =[32]))

C2 = tf.nn.conv2d(A1, W2, strides= [1, 1, 1, 1], padding= 'SAME')

Z2 = tf.nn.relu(C2 + b2)

A2 = P2 = tf.nn.max_pool(Z2, ksize = [1, 2, 2, 1], strides= [ 1, 2, 2, 1], padding= 'SAME')

# %%
A2_flat = P2_flat = tf.reshape(A2, [-1, 14*14*32])

# %%
#출력층
W3 = tf.Variable(tf.random_normal([14*14*32, 10], stddev = 0.01))
b3 = tf.Variable(tf.random_normal([10]))

Z3 = logits = tf.matmul(A2_flat, W3) + b3

y = A3 = tf.nn.softmax(Z3)

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits = Z3, labels = T))

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
predicted_val = tf.equal(tf.argmax(A3, 1), tf.argmax(T, 1))

accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype = tf.float32))

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    start_time = datetime.now()
    
    for i in range(epochs):
        total_batch = int(mnist.train.num_examples / batch_size)
        
        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
            
            loss_val, _ = sess.run([loss, train], feed_dict = {X : batch_x_data, T : batch_t_data})
            
            if step % 100 == 0:
                print("epochs = ", i, "step = ", step, ", loss_val = ", loss_val)
    end_time = datetime.now()
    
    print("\n Elapsed Time : ", end_time - start_time)
    
    test_x_data = mnist.test.images
    test_t_data = mnist.test.labels
    
    accuracy_val = sess.run(accuracy, feed_dict = {X : test_x_data, T: test_t_data})
    print("\n accuracy = ", accuracy_val)
# Out:
# epochs =  0 step =  0 , loss_val =  2.5475492
# epochs =  0 step =  100 , loss_val =  1.1894839
# epochs =  0 step =  200 , loss_val =  0.52376294
# epochs =  0 step =  300 , loss_val =  0.33988166
# epochs =  0 step =  400 , loss_val =  0.48084137
# epochs =  0 step =  500 , loss_val =  0.40199113
# epochs =  1 step =  0 , loss_val =  0.43068284
# epochs =  1 step =  100 , loss_val =  0.34503952
# epochs =  1 step =  200 , loss_val =  0.33032256
# epochs =  1 step =  300 , loss_val =  0.30608514
# epochs =  1 step =  400 , loss_val =  0.29030865
# epochs =  1 step =  500 , loss_val =  0.35445666
# epochs =  2 step =  0 , loss_val =  0.20256038
# epochs =  2 step =  100 , loss_val =  0.18940967
# epochs =  2 step =  200 , loss_val =  0.3449033
# epochs =  2 step =  300 , loss_val =  0.18575323
# epochs =  2 step =  400 , loss_val =  0.28684482
# epochs =  2 step =  500 , loss_val =  0.14201051
# epochs =  3 step =  0 , loss_val =  0.2655636
# epochs =  3 step =  100 , loss_val =  0.3967307
# epochs =  3 step =  200 , loss_val =  0.31197274
# epochs =  3 step =  300 , loss_val =  0.2946772
# epochs =  3 step =  400 , loss_val =  0.18542734
# epochs =  3 step =  500 , loss_val =  0.25304016
# epochs =  4 step =  0 , loss_val =  0.20469365
# epochs =  4 step =  100 , loss_val =  0.19897127
# epochs =  4 step =  200 , loss_val =  0.17246442
# epochs =  4 step =  300 , loss_val =  0.2422292
# epochs =  4 step =  400 , loss_val =  0.24280305
# epochs =  4 step =  500 , loss_val =  0.29704002
# epochs =  5 step =  0 , loss_val =  0.21109082
# epochs =  5 step =  100 , loss_val =  0.26985165
# epochs =  5 step =  200 , loss_val =  0.1953682
# epochs =  5 step =  300 , loss_val =  0.14367928
# epochs =  5 step =  400 , loss_val =  0.16251644
# epochs =  5 step =  500 , loss_val =  0.051523343
# epochs =  6 step =  0 , loss_val =  0.18345323
# epochs =  6 step =  100 , loss_val =  0.17708354
# epochs =  6 step =  200 , loss_val =  0.08077646
# epochs =  6 step =  300 , loss_val =  0.07052705
# epochs =  6 step =  400 , loss_val =  0.0429378
# epochs =  6 step =  500 , loss_val =  0.047904834
# epochs =  7 step =  0 , loss_val =  0.0701059
# epochs =  7 step =  100 , loss_val =  0.07829803
# epochs =  7 step =  200 , loss_val =  0.061485756
# epochs =  7 step =  300 , loss_val =  0.21948059
# epochs =  7 step =  400 , loss_val =  0.07528673
# epochs =  7 step =  500 , loss_val =  0.15982163
# epochs =  8 step =  0 , loss_val =  0.064415514
# epochs =  8 step =  100 , loss_val =  0.10335213
# epochs =  8 step =  200 , loss_val =  0.20993744
# epochs =  8 step =  300 , loss_val =  0.13354123
# epochs =  8 step =  400 , loss_val =  0.036382604
# epochs =  8 step =  500 , loss_val =  0.06351314
# epochs =  9 step =  0 , loss_val =  0.06642463
# epochs =  9 step =  100 , loss_val =  0.055033293
# epochs =  9 step =  200 , loss_val =  0.14612539
# epochs =  9 step =  300 , loss_val =  0.042934235
# epochs =  9 step =  400 , loss_val =  0.0990291
# epochs =  9 step =  500 , loss_val =  0.04556102
# epochs =  10 step =  0 , loss_val =  0.021976702
# epochs =  10 step =  100 , loss_val =  0.1708244
# epochs =  10 step =  200 , loss_val =  0.11679656
# epochs =  10 step =  300 , loss_val =  0.06062978
# epochs =  10 step =  400 , loss_val =  0.030659728
# epochs =  10 step =  500 , loss_val =  0.15738563
# epochs =  11 step =  0 , loss_val =  0.015014542
# epochs =  11 step =  100 , loss_val =  0.16089493
# epochs =  11 step =  200 , loss_val =  0.12434333
# epochs =  11 step =  300 , loss_val =  0.022812199
# epochs =  11 step =  400 , loss_val =  0.06028618
# epochs =  11 step =  500 , loss_val =  0.07866827
# epochs =  12 step =  0 , loss_val =  0.1394058
# epochs =  12 step =  100 , loss_val =  0.03303085
# epochs =  12 step =  200 , loss_val =  0.067298986
# epochs =  12 step =  300 , loss_val =  0.050386995
# epochs =  12 step =  400 , loss_val =  0.037005793
# epochs =  12 step =  500 , loss_val =  0.023875572
# epochs =  13 step =  0 , loss_val =  0.019505475
# epochs =  13 step =  100 , loss_val =  0.070227355
# epochs =  13 step =  200 , loss_val =  0.017401969
# epochs =  13 step =  300 , loss_val =  0.0526668
# epochs =  13 step =  400 , loss_val =  0.07242516
# epochs =  13 step =  500 , loss_val =  0.022860385
# epochs =  14 step =  0 , loss_val =  0.015183029
# epochs =  14 step =  100 , loss_val =  0.016991546
# epochs =  14 step =  200 , loss_val =  0.027122319
# epochs =  14 step =  300 , loss_val =  0.019519664
# epochs =  14 step =  400 , loss_val =  0.0748623
# epochs =  14 step =  500 , loss_val =  0.104572676
# epochs =  15 step =  0 , loss_val =  0.07784044
# epochs =  15 step =  100 , loss_val =  0.039629713
# epochs =  15 step =  200 , loss_val =  0.021473985
# epochs =  15 step =  300 , loss_val =  0.047292415
# epochs =  15 step =  400 , loss_val =  0.14811665
# epochs =  15 step =  500 , loss_val =  0.049199086
# epochs =  16 step =  0 , loss_val =  0.06360072
# epochs =  16 step =  100 , loss_val =  0.038894664
# epochs =  16 step =  200 , loss_val =  0.081816055
# epochs =  16 step =  300 , loss_val =  0.19502048
# epochs =  16 step =  400 , loss_val =  0.035564333
# epochs =  16 step =  500 , loss_val =  0.07707433
# epochs =  17 step =  0 , loss_val =  0.03292004
# epochs =  17 step =  100 , loss_val =  0.009562322
# epochs =  17 step =  200 , loss_val =  0.03550553
# epochs =  17 step =  300 , loss_val =  0.03548398
# epochs =  17 step =  400 , loss_val =  0.042510625
# epochs =  17 step =  500 , loss_val =  0.07074353
# epochs =  18 step =  0 , loss_val =  0.017457169
# epochs =  18 step =  100 , loss_val =  0.009343049
# epochs =  18 step =  200 , loss_val =  0.01122226
# epochs =  18 step =  300 , loss_val =  0.005772052
# epochs =  18 step =  400 , loss_val =  0.057772215
# epochs =  18 step =  500 , loss_val =  0.010224235
# epochs =  19 step =  0 , loss_val =  0.07409596
# epochs =  19 step =  100 , loss_val =  0.01717148
# epochs =  19 step =  200 , loss_val =  0.014225789
# epochs =  19 step =  300 , loss_val =  0.059198447
# epochs =  19 step =  400 , loss_val =  0.04108976
# epochs =  19 step =  500 , loss_val =  0.095748395
# epochs =  20 step =  0 , loss_val =  0.023886008
# epochs =  20 step =  100 , loss_val =  0.01424135
# epochs =  20 step =  200 , loss_val =  0.044468604
# epochs =  20 step =  300 , loss_val =  0.02215542
# epochs =  20 step =  400 , loss_val =  0.01782249
# epochs =  20 step =  500 , loss_val =  0.031954046
# epochs =  21 step =  0 , loss_val =  0.0071537723
# epochs =  21 step =  100 , loss_val =  0.023021113
# epochs =  21 step =  200 , loss_val =  0.016781967
# epochs =  21 step =  300 , loss_val =  0.06551979
# epochs =  21 step =  400 , loss_val =  0.07325103
# epochs =  21 step =  500 , loss_val =  0.007449055
# epochs =  22 step =  0 , loss_val =  0.052396875
# epochs =  22 step =  100 , loss_val =  0.047079757
# epochs =  22 step =  200 , loss_val =  0.0075613055
# epochs =  22 step =  300 , loss_val =  0.044495076
# epochs =  22 step =  400 , loss_val =  0.010379648
# epochs =  22 step =  500 , loss_val =  0.035994656
# epochs =  23 step =  0 , loss_val =  0.0037046983
# epochs =  23 step =  100 , loss_val =  0.01587036
# epochs =  23 step =  200 , loss_val =  0.019339846
# epochs =  23 step =  300 , loss_val =  0.025114987
# epochs =  23 step =  400 , loss_val =  0.01966638
# epochs =  23 step =  500 , loss_val =  0.0070482455
# epochs =  24 step =  0 , loss_val =  0.0054251994
# epochs =  24 step =  100 , loss_val =  0.0014412653
# epochs =  24 step =  200 , loss_val =  0.0053173816
# epochs =  24 step =  300 , loss_val =  0.09420285
# epochs =  24 step =  400 , loss_val =  0.047225103
# epochs =  24 step =  500 , loss_val =  0.00847847
# epochs =  25 step =  0 , loss_val =  0.024709582
# epochs =  25 step =  100 , loss_val =  0.0053211194
# epochs =  25 step =  200 , loss_val =  0.04988439
# epochs =  25 step =  300 , loss_val =  0.014952123
# epochs =  25 step =  400 , loss_val =  0.02043005
# epochs =  25 step =  500 , loss_val =  0.015024438
# epochs =  26 step =  0 , loss_val =  0.015907507
# epochs =  26 step =  100 , loss_val =  0.0065851863
# epochs =  26 step =  200 , loss_val =  0.06045636
# epochs =  26 step =  300 , loss_val =  0.020712739
# epochs =  26 step =  400 , loss_val =  0.10242077
# epochs =  26 step =  500 , loss_val =  0.033289175
# epochs =  27 step =  0 , loss_val =  0.008492957
# epochs =  27 step =  100 , loss_val =  0.015945023
# epochs =  27 step =  200 , loss_val =  0.02578213
# epochs =  27 step =  300 , loss_val =  0.008221214
# epochs =  27 step =  400 , loss_val =  0.006821484
# epochs =  27 step =  500 , loss_val =  0.012859373
# epochs =  28 step =  0 , loss_val =  0.005094117
# epochs =  28 step =  100 , loss_val =  0.0108340625
# epochs =  28 step =  200 , loss_val =  0.0036428145
# epochs =  28 step =  300 , loss_val =  0.0066352203
# epochs =  28 step =  400 , loss_val =  0.011988577
# epochs =  28 step =  500 , loss_val =  0.01651746
# epochs =  29 step =  0 , loss_val =  0.026720202
# epochs =  29 step =  100 , loss_val =  0.018538307
# epochs =  29 step =  200 , loss_val =  0.027433882
# epochs =  29 step =  300 , loss_val =  0.012542278
# epochs =  29 step =  400 , loss_val =  0.0054444433
# epochs =  29 step =  500 , loss_val =  0.011148434
#
#  Elapsed Time :  0:13:17.461593
#
#  accuracy =  0.981

# %%
# ?tf.constant
