# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime
import os
mnist = input_data.read_data_sets("MNIST_data/", one_hot = True)

print("")
print("train.num = ", mnist.train.num_examples)
print("test.num = ", mnist.test.num_examples)
print("validation.num = ", mnist.validation.num_examples)
# Out:
# WARNING:tensorflow:From <ipython-input-1-7ff89608d47c>:6: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
# train.num =  55000
# test.num =  10000
# validation.num =  5000

# %%
learning_rate = 0.001 # 학습율
epochs = 30 # 반복횟수
batch_size = 100 #한번에 입력으로 주어지는 MNIST 개수

# %%
X = tf.placeholder(tf.float32, [None, 784]) # 28 x 28

T = tf.placeholder(tf.float32, [None, 10]) # 정답데이터 10개

A1 = tf.reshape(X, [-1, 28, 28, 1]) # image 28 x 28 x 1 (black / white)

# %%
W2 = tf.Variable(tf.random_normal([5, 5, 1, 32], stddev = 0.01))

b2 = tf.Variable(tf.constant(0.1, shape =[32]))

C2 = tf.nn.conv2d(A1, W2, strides= [1, 1, 1, 1], padding= 'SAME')

Z2 = tf.nn.relu(C2 + b2)

A2 = P2 = tf.nn.max_pool(Z2, ksize = [1, 2, 2, 1], strides= [ 1, 2, 2, 1], padding= 'SAME')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
A2_flat = P2_flat = tf.reshape(A2, [-1, 14*14*32])

# %%
#출력층
W3 = tf.Variable(tf.random_normal([14*14*32, 10], stddev = 0.01))
b3 = tf.Variable(tf.random_normal([10]))

Z3 = logits = tf.matmul(A2_flat, W3) + b3

y = A3 = tf.nn.softmax(Z3)

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits = Z3, labels = T))

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
predicted_val = tf.equal(tf.argmax(A3, 1), tf.argmax(T, 1))

accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype = tf.float32))

# %%
import math
# tf.train.Saver를 이용하여 모델과 파라미터를 저장합니다.
save_file = './train_model.ckpt'
saver = tf.train.Saver()


#세션을 열어 실제 학습을 진행합니다.
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    start_time = datetime.now()
    
    for i in range(epochs):
        total_batch = int(mnist.train.num_examples / batch_size)
        
        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
            
            loss_val, _ = sess.run([loss, train], feed_dict = {X : batch_x_data, T : batch_t_data})
            
            if step % 100 == 0:
                
                
                print("epochs = ", i, "step = ", step, ", loss_val = ", loss_val)
                
    saver.save(sess, save_file)
        
    end_time = datetime.now()
    
    print("\n Elapsed Time : ", end_time - start_time)
    
    test_x_data = mnist.test.images
    test_t_data = mnist.test.labels
    
    accuracy_val = sess.run(accuracy, feed_dict = {X : test_x_data, T: test_t_data})
    print("\n accuracy = ", accuracy_val)
# Out:
# epochs =  0 step =  0 , loss_val =  2.6003203
# epochs =  0 step =  100 , loss_val =  0.3436643
# epochs =  0 step =  200 , loss_val =  0.2895384
# epochs =  0 step =  300 , loss_val =  0.20639676
# epochs =  0 step =  400 , loss_val =  0.22305007
# epochs =  0 step =  500 , loss_val =  0.07713587
# epochs =  1 step =  0 , loss_val =  0.13649327
# epochs =  1 step =  100 , loss_val =  0.08021065
# epochs =  1 step =  200 , loss_val =  0.122491226
# epochs =  1 step =  300 , loss_val =  0.1078634
# epochs =  1 step =  400 , loss_val =  0.1385201
# epochs =  1 step =  500 , loss_val =  0.11014969
# epochs =  2 step =  0 , loss_val =  0.12420795
# epochs =  2 step =  100 , loss_val =  0.03534077
# epochs =  2 step =  200 , loss_val =  0.05414306
# epochs =  2 step =  300 , loss_val =  0.19190432
# epochs =  2 step =  400 , loss_val =  0.08398366
# epochs =  2 step =  500 , loss_val =  0.09238453
# epochs =  3 step =  0 , loss_val =  0.07404413
# epochs =  3 step =  100 , loss_val =  0.025718214
# epochs =  3 step =  200 , loss_val =  0.08100087
# epochs =  3 step =  300 , loss_val =  0.08617945
# epochs =  3 step =  400 , loss_val =  0.028255334
# epochs =  3 step =  500 , loss_val =  0.08421751
# epochs =  4 step =  0 , loss_val =  0.032836203
# epochs =  4 step =  100 , loss_val =  0.037125386
# epochs =  4 step =  200 , loss_val =  0.095722504
# epochs =  4 step =  300 , loss_val =  0.013950085
# epochs =  4 step =  400 , loss_val =  0.01387224
# epochs =  4 step =  500 , loss_val =  0.052907538
# epochs =  5 step =  0 , loss_val =  0.006940495
# epochs =  5 step =  100 , loss_val =  0.013043926
# epochs =  5 step =  200 , loss_val =  0.040662643
# epochs =  5 step =  300 , loss_val =  0.04175062
# epochs =  5 step =  400 , loss_val =  0.009420249
# epochs =  5 step =  500 , loss_val =  0.10170698
# epochs =  6 step =  0 , loss_val =  0.028776549
# epochs =  6 step =  100 , loss_val =  0.026499186
# epochs =  6 step =  200 , loss_val =  0.039663807
# epochs =  6 step =  300 , loss_val =  0.0258352
# epochs =  6 step =  400 , loss_val =  0.029818943
# epochs =  6 step =  500 , loss_val =  0.019818164
# epochs =  7 step =  0 , loss_val =  0.015320349
# epochs =  7 step =  100 , loss_val =  0.008324803
# epochs =  7 step =  200 , loss_val =  0.019429386
# epochs =  7 step =  300 , loss_val =  0.046096805
# epochs =  7 step =  400 , loss_val =  0.08103936
# epochs =  7 step =  500 , loss_val =  0.007638155
# epochs =  8 step =  0 , loss_val =  0.013337534
# epochs =  8 step =  100 , loss_val =  0.010713811
# epochs =  8 step =  200 , loss_val =  0.025393631
# epochs =  8 step =  300 , loss_val =  0.04197497
# epochs =  8 step =  400 , loss_val =  0.009962288
# epochs =  8 step =  500 , loss_val =  0.037545428
# epochs =  9 step =  0 , loss_val =  0.0024255204
# epochs =  9 step =  100 , loss_val =  0.006145465
# epochs =  9 step =  200 , loss_val =  0.055238858
# epochs =  9 step =  300 , loss_val =  0.026862808
# epochs =  9 step =  400 , loss_val =  0.04275985
# epochs =  9 step =  500 , loss_val =  0.01763505
# epochs =  10 step =  0 , loss_val =  0.00634107
# epochs =  10 step =  100 , loss_val =  0.02924205
# epochs =  10 step =  200 , loss_val =  0.006604225
# epochs =  10 step =  300 , loss_val =  0.03192692
# epochs =  10 step =  400 , loss_val =  0.06560003
# epochs =  10 step =  500 , loss_val =  0.013427501
# epochs =  11 step =  0 , loss_val =  0.008753527
# epochs =  11 step =  100 , loss_val =  0.0051570293
# epochs =  11 step =  200 , loss_val =  0.030864539
# epochs =  11 step =  300 , loss_val =  0.016297929
# epochs =  11 step =  400 , loss_val =  0.012497497
# epochs =  11 step =  500 , loss_val =  0.027540792
# epochs =  21 step =  400 , loss_val =  0.0029236942
# epochs =  21 step =  500 , loss_val =  0.023454973
# epochs =  22 step =  0 , loss_val =  0.013790291
# epochs =  22 step =  100 , loss_val =  0.0018318003
# epochs =  22 step =  200 , loss_val =  0.0012084342
# epochs =  22 step =  300 , loss_val =  0.009901075
# epochs =  22 step =  400 , loss_val =  0.0011510998
# epochs =  22 step =  500 , loss_val =  0.00041875165
# epochs =  23 step =  0 , loss_val =  0.0016377089
# epochs =  23 step =  100 , loss_val =  0.0010167725
# epochs =  23 step =  200 , loss_val =  0.006666683
# epochs =  23 step =  300 , loss_val =  0.00131159
# epochs =  23 step =  400 , loss_val =  0.0012248601
# epochs =  23 step =  500 , loss_val =  0.0023445764
# epochs =  24 step =  0 , loss_val =  0.0005939469
# epochs =  24 step =  100 , loss_val =  0.00091300585
# epochs =  24 step =  200 , loss_val =  0.0031425208
# epochs =  24 step =  300 , loss_val =  0.003733185
# epochs =  24 step =  400 , loss_val =  0.010034693
# epochs =  24 step =  500 , loss_val =  0.00013162533
# epochs =  25 step =  0 , loss_val =  0.00045906767
# epochs =  25 step =  100 , loss_val =  0.0006100886
# epochs =  25 step =  200 , loss_val =  0.0061451984
# epochs =  25 step =  300 , loss_val =  0.004866669
# epochs =  25 step =  400 , loss_val =  0.0032074072
# epochs =  25 step =  500 , loss_val =  0.012707842
# epochs =  26 step =  0 , loss_val =  0.0011050709
# epochs =  26 step =  100 , loss_val =  0.0019449121
# epochs =  26 step =  200 , loss_val =  0.0030754507
# epochs =  26 step =  300 , loss_val =  0.0010923267
# epochs =  26 step =  400 , loss_val =  0.007305113
# epochs =  26 step =  500 , loss_val =  5.6758672e-05
# epochs =  27 step =  0 , loss_val =  0.0028241086
# epochs =  27 step =  100 , loss_val =  0.001427984
# epochs =  27 step =  200 , loss_val =  0.00022780914
# epochs =  27 step =  300 , loss_val =  0.00011636858
# epochs =  27 step =  400 , loss_val =  0.0014956483
# epochs =  27 step =  500 , loss_val =  0.00093323947
# epochs =  28 step =  0 , loss_val =  0.00080596143
# epochs =  28 step =  100 , loss_val =  0.0003285622
# epochs =  28 step =  200 , loss_val =  0.0014684859
# epochs =  28 step =  300 , loss_val =  0.023669917
# epochs =  28 step =  400 , loss_val =  0.00036747567
# epochs =  28 step =  500 , loss_val =  2.8436094e-05
# epochs =  29 step =  0 , loss_val =  0.0019870668
# epochs =  29 step =  100 , loss_val =  0.00013434855
# epochs =  29 step =  200 , loss_val =  0.0005318035
# epochs =  29 step =  300 , loss_val =  0.00017364364
# epochs =  29 step =  400 , loss_val =  0.000113554
# epochs =  29 step =  500 , loss_val =  0.0016836469
#
#  Elapsed Time :  0:24:01.357809
#
#  accuracy =  0.9867

# %%
with tf.Session() as sess:
    saver.restore(sess, save_file)
    
    test_x_data = mnist.test.images
    test_t_data = mnist.test.labels
    
    accuracy_val = sess.run(accuracy, feed_dict = {X : test_x_data, T : test_t_data})
    
    print("accuracy = ", accuracy_val)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./train_model.ckpt
# accuracy =  0.9867
